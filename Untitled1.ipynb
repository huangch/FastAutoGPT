# %% [markdown]
# <a href="https://colab.research.google.com/github/huangch/FastAutoGPT/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from scipy.spatial import Delaunay
from scipy.sparse import csr_matrix

# ---------- pseudo data ----------
def make_cells(n=3000, width=2048, height=2048, seed=42):
    rng = np.random.default_rng(seed)
    x = rng.uniform(0, width, n); y = rng.uniform(0, height, n)
    labels = np.array(["lymphocyte", "tumor", "others"])
    ann = rng.choice(labels, size=n, p=[0.33, 0.34, 0.33])
    return pd.DataFrame({"x": x, "y": y, "cell_annotation": pd.Categorical(ann, categories=labels)})

# ---------- fast Delaunay + CSR neighbors ----------
def delaunay_triangulation_fast(points: np.ndarray,
                                qhull_options: str = "Qbb Qc QJ",
                                need_triangles: bool = False,
                                need_edges: bool = False):
    P = np.ascontiguousarray(points, dtype=np.float64)
    uniq_pts, uniq_to_orig, orig_to_uniq = np.unique(P, axis=0, return_index=True, return_inverse=True)
    if uniq_pts.shape[0] < 3:
        raise ValueError("Need at least 3 unique points for 2D Delaunay.")
    tri = Delaunay(uniq_pts, qhull_options=qhull_options)  # no Qz
    indptr_u, indices_u = tri.vertex_neighbor_vertices
    indices_orig = uniq_to_orig[indices_u]
    simplices = edges = None
    if need_triangles or need_edges:
        simplices = uniq_to_orig[tri.simplices]
    if need_edges:
        a, b, c = simplices.T
        edges_raw = np.vstack([np.c_[a, b], np.c_[b, c], np.c_[c, a]])
        edges = np.unique(np.sort(edges_raw, axis=1), axis=0)
    return (tri, indptr_u, indices_u, indices_orig, orig_to_uniq, uniq_to_orig, simplices, edges)

# ---------- ALL nodes k-hop neighborhoods (batch, sparse) ----------
def k_hop_all_nodes(indptr_u: np.ndarray,
                    indices_u: np.ndarray,
                    orig_to_uniq: np.ndarray,
                    uniq_to_orig: np.ndarray,
                    k: int,
                    include_start: bool = False):
    """
    Returns a list of np.ndarrays: for each ORIGINAL node i, all ORIGINAL ids within <= k hops.
    """
    n = indptr_u.size - 1
    if k < 0:
        raise ValueError("k must be >= 0")

    # Build symmetric boolean adjacency A (unique index space)
    rows = np.repeat(np.arange(n), np.diff(indptr_u))
    cols = indices_u
    data = np.ones_like(cols, dtype=bool)
    A = csr_matrix((data, (rows, cols)), shape=(n, n), dtype=bool)
    A = A.maximum(A.T)           # symmetrize
    A.setdiag(False); A.eliminate_zeros()

    if k == 0:
        R = csr_matrix((n, n), dtype=bool)  # empty reachability
    else:
        R = A.copy()
        frontier = A.copy()
        for _ in range(2, k + 1):
            frontier = (frontier @ A).astype(bool)
            frontier.eliminate_zeros()
            R = R.maximum(frontier)         # boolean OR

    if include_start:
        R.setdiag(True)

    # Collect neighbors per UNIQUE node, then map to ORIGINAL ids.
    neigh_u = [uniq_to_orig[R.indices[R.indptr[u]:R.indptr[u+1]]] for u in range(n)]
    return [neigh_u[orig_to_uniq[i]] for i in range(orig_to_uniq.size)]

# ---------- example: run with k=2 over all nodes ----------
if __name__ == "__main__":
    df = make_cells(n=3000, width=2048, height=2048, seed=7)
    points = df[["x", "y"]].to_numpy(copy=False)

    (tri, indptr_u, indices_u, indices_orig,
     orig2uniq, uniq2orig, _, _) = delaunay_triangulation_fast(points,
                                                               need_triangles=False,
                                                               need_edges=False)

    k = 2
    neighbors_k = k_hop_all_nodes(indptr_u, indices_u, orig2uniq, uniq2orig, k=k, include_start=False)

    # demo: inspect a few nodes
    for i in [0, 1, 2, 123]:
        ids = neighbors_k[i]
        print(f"node {i}: {len(ids)} nodes within <= {k} hops")
        print(df.loc[ids, "cell_annotation"].value_counts(), "\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Name: count, dtype: int64
#
# node 2286: 25 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor          8
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2287: 21 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          6
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2288: 18 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    6
# tumor         3
# Name: count, dtype: int64
#
# node 2289: 14 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        5
# tumor         3
# Name: count, dtype: int64
#
# node 2290: 14 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         5
# others        3
# Name: count, dtype: int64
#
# node 2291: 15 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    4
# others        3
# Name: count, dtype: int64
#
# node 2292: 25 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          9
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2293: 15 nodes within <= 2 hops
# cell_annotation
# tumor         6
# lymphocyte    5
# others        4
# Name: count, dtype: int64
#
# node 2294: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        8
# tumor         3
# Name: count, dtype: int64
#
# node 2295: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2296: 17 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    5
# others        4
# Name: count, dtype: int64
#
# node 2297: 17 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          5
# lymphocyte     2
# Name: count, dtype: int64
#
# node 2298: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2299: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         5
# Name: count, dtype: int64
#
# node 2300: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    7
# tumor         5
# Name: count, dtype: int64
#
# node 2301: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          7
# others         6
# Name: count, dtype: int64
#
# node 2302: 21 nodes within <= 2 hops
# cell_annotation
# tumor         14
# lymphocyte     5
# others         2
# Name: count, dtype: int64
#
# node 2303: 24 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor          7
# others         6
# Name: count, dtype: int64
#
# node 2304: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         7
# others        4
# Name: count, dtype: int64
#
# node 2305: 26 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor          8
# others         7
# Name: count, dtype: int64
#
# node 2306: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          8
# others         5
# Name: count, dtype: int64
#
# node 2307: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         6
# Name: count, dtype: int64
#
# node 2308: 29 nodes within <= 2 hops
# cell_annotation
# others        14
# lymphocyte    10
# tumor          5
# Name: count, dtype: int64
#
# node 2309: 26 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         9
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2310: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         6
# Name: count, dtype: int64
#
# node 2311: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         8
# others        7
# Name: count, dtype: int64
#
# node 2312: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         5
# tumor          2
# Name: count, dtype: int64
#
# node 2313: 25 nodes within <= 2 hops
# cell_annotation
# tumor         12
# others         7
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2314: 23 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         7
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2315: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         6
# Name: count, dtype: int64
#
# node 2316: 15 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         4
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2317: 26 nodes within <= 2 hops
# cell_annotation
# tumor         11
# lymphocyte     8
# others         7
# Name: count, dtype: int64
#
# node 2318: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         7
# others        6
# Name: count, dtype: int64
#
# node 2319: 19 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2320: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         7
# others        4
# Name: count, dtype: int64
#
# node 2321: 25 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        9
# lymphocyte    7
# Name: count, dtype: int64
#
# node 2322: 22 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        8
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2323: 15 nodes within <= 2 hops
# cell_annotation
# others        7
# tumor         5
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2324: 18 nodes within <= 2 hops
# cell_annotation
# tumor         7
# lymphocyte    6
# others        5
# Name: count, dtype: int64
#
# node 2325: 15 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         5
# others        4
# Name: count, dtype: int64
#
# node 2326: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2327: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2328: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         7
# others        4
# Name: count, dtype: int64
#
# node 2329: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        9
# tumor         3
# Name: count, dtype: int64
#
# node 2330: 17 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        7
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2331: 25 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         8
# others        8
# Name: count, dtype: int64
#
# node 2332: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        8
# tumor         6
# Name: count, dtype: int64
#
# node 2333: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2334: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2335: 20 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2336: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         6
# others        5
# Name: count, dtype: int64
#
# node 2337: 24 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        9
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2338: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    6
# tumor         6
# Name: count, dtype: int64
#
# node 2339: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         6
# Name: count, dtype: int64
#
# node 2340: 22 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          8
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2341: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         6
# others        4
# Name: count, dtype: int64
#
# node 2342: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         4
# Name: count, dtype: int64
#
# node 2343: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         8
# others        4
# Name: count, dtype: int64
#
# node 2344: 18 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         4
# Name: count, dtype: int64
#
# node 2345: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         5
# others        3
# Name: count, dtype: int64
#
# node 2346: 22 nodes within <= 2 hops
# cell_annotation
# tumor         11
# lymphocyte     6
# others         5
# Name: count, dtype: int64
#
# node 2347: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2348: 17 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    4
# others        4
# Name: count, dtype: int64
#
# node 2349: 52 nodes within <= 2 hops
# cell_annotation
# tumor         21
# others        17
# lymphocyte    14
# Name: count, dtype: int64
#
# node 2350: 22 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         8
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2351: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         4
# others        4
# Name: count, dtype: int64
#
# node 2352: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         5
# others        4
# Name: count, dtype: int64
#
# node 2353: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        5
# tumor         3
# Name: count, dtype: int64
#
# node 2354: 17 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2355: 19 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    6
# tumor         4
# Name: count, dtype: int64
#
# node 2356: 18 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    7
# tumor         3
# Name: count, dtype: int64
#
# node 2357: 26 nodes within <= 2 hops
# cell_annotation
# tumor         13
# lymphocyte     8
# others         5
# Name: count, dtype: int64
#
# node 2358: 22 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         7
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2359: 26 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         9
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2360: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2361: 29 nodes within <= 2 hops
# cell_annotation
# tumor         14
# lymphocyte     9
# others         6
# Name: count, dtype: int64
#
# node 2362: 23 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          9
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2363: 22 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     8
# tumor          4
# Name: count, dtype: int64
#
# node 2364: 26 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor         10
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2365: 15 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         3
# Name: count, dtype: int64
#
# node 2366: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         6
# others        6
# Name: count, dtype: int64
#
# node 2367: 17 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         6
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2368: 19 nodes within <= 2 hops
# cell_annotation
# others        7
# lymphocyte    6
# tumor         6
# Name: count, dtype: int64
#
# node 2369: 20 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     5
# tumor          5
# Name: count, dtype: int64
#
# node 2370: 23 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     7
# tumor          6
# Name: count, dtype: int64
#
# node 2371: 19 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         5
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2372: 18 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    5
# others        4
# Name: count, dtype: int64
#
# node 2373: 15 nodes within <= 2 hops
# cell_annotation
# others        6
# tumor         5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2374: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         5
# Name: count, dtype: int64
#
# node 2375: 19 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    7
# others        4
# Name: count, dtype: int64
#
# node 2376: 19 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    7
# tumor         3
# Name: count, dtype: int64
#
# node 2377: 16 nodes within <= 2 hops
# cell_annotation
# tumor         6
# others        6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2378: 23 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    8
# others        6
# Name: count, dtype: int64
#
# node 2379: 19 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         5
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2380: 15 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         4
# others        4
# Name: count, dtype: int64
#
# node 2381: 18 nodes within <= 2 hops
# cell_annotation
# others        12
# lymphocyte     5
# tumor          1
# Name: count, dtype: int64
#
# node 2382: 25 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          9
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2383: 19 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    7
# others        4
# Name: count, dtype: int64
#
# node 2384: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        7
# tumor         4
# Name: count, dtype: int64
#
# node 2385: 13 nodes within <= 2 hops
# cell_annotation
# others        6
# lymphocyte    5
# tumor         2
# Name: count, dtype: int64
#
# node 2386: 14 nodes within <= 2 hops
# cell_annotation
# lymphocyte    5
# tumor         5
# others        4
# Name: count, dtype: int64
#
# node 2387: 20 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others         8
# lymphocyte     1
# Name: count, dtype: int64
#
# node 2388: 19 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2389: 29 nodes within <= 2 hops
# cell_annotation
# others        14
# lymphocyte    10
# tumor          5
# Name: count, dtype: int64
#
# node 2390: 19 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor          5
# lymphocyte     3
# Name: count, dtype: int64
#
# node 2391: 18 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        8
# lymphocyte    2
# Name: count, dtype: int64
#
# node 2392: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# others         7
# tumor          4
# Name: count, dtype: int64
#
# node 2393: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         6
# others        5
# Name: count, dtype: int64
#
# node 2394: 24 nodes within <= 2 hops
# cell_annotation
# tumor         11
# lymphocyte     7
# others         6
# Name: count, dtype: int64
#
# node 2395: 13 nodes within <= 2 hops
# cell_annotation
# tumor         5
# lymphocyte    4
# others        4
# Name: count, dtype: int64
#
# node 2396: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         5
# others        5
# Name: count, dtype: int64
#
# node 2397: 22 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others         7
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2398: 26 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     9
# others         7
# Name: count, dtype: int64
#
# node 2399: 21 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     7
# others         4
# Name: count, dtype: int64
#
# node 2400: 21 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        7
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2401: 24 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others         8
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2402: 26 nodes within <= 2 hops
# cell_annotation
# tumor         14
# others         7
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2403: 25 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     8
# tumor          6
# Name: count, dtype: int64
#
# node 2404: 20 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        7
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2405: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2406: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    7
# tumor         5
# Name: count, dtype: int64
#
# node 2407: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2408: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         6
# others        4
# Name: count, dtype: int64
#
# node 2409: 25 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# others         8
# tumor          4
# Name: count, dtype: int64
#
# node 2410: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         8
# tumor          1
# Name: count, dtype: int64
#
# node 2411: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    6
# others        6
# Name: count, dtype: int64
#
# node 2412: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         8
# others        4
# Name: count, dtype: int64
#
# node 2413: 23 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     8
# others         5
# Name: count, dtype: int64
#
# node 2414: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         7
# others        7
# Name: count, dtype: int64
#
# node 2415: 23 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          8
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2416: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         5
# others        5
# Name: count, dtype: int64
#
# node 2417: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         7
# tumor          5
# Name: count, dtype: int64
#
# node 2418: 26 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         9
# others        8
# Name: count, dtype: int64
#
# node 2419: 18 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    5
# tumor         4
# Name: count, dtype: int64
#
# node 2420: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         7
# others        4
# Name: count, dtype: int64
#
# node 2421: 24 nodes within <= 2 hops
# cell_annotation
# tumor         12
# lymphocyte     6
# others         6
# Name: count, dtype: int64
#
# node 2422: 16 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         4
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2423: 27 nodes within <= 2 hops
# cell_annotation
# lymphocyte    14
# tumor          8
# others         5
# Name: count, dtype: int64
#
# node 2424: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2425: 27 nodes within <= 2 hops
# cell_annotation
# lymphocyte    12
# tumor          9
# others         6
# Name: count, dtype: int64
#
# node 2426: 23 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    7
# tumor         7
# Name: count, dtype: int64
#
# node 2427: 24 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        8
# tumor         7
# Name: count, dtype: int64
#
# node 2428: 15 nodes within <= 2 hops
# cell_annotation
# others        7
# lymphocyte    6
# tumor         2
# Name: count, dtype: int64
#
# node 2429: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         7
# others        3
# Name: count, dtype: int64
#
# node 2430: 25 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         8
# others        8
# Name: count, dtype: int64
#
# node 2431: 19 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         7
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2432: 29 nodes within <= 2 hops
# cell_annotation
# tumor         13
# lymphocyte    10
# others         6
# Name: count, dtype: int64
#
# node 2433: 15 nodes within <= 2 hops
# cell_annotation
# tumor         6
# others        6
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2434: 24 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor          9
# others         4
# Name: count, dtype: int64
#
# node 2435: 12 nodes within <= 2 hops
# cell_annotation
# others        6
# lymphocyte    3
# tumor         3
# Name: count, dtype: int64
#
# node 2436: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        8
# tumor         5
# Name: count, dtype: int64
#
# node 2437: 18 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         6
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2438: 33 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# others        13
# tumor          7
# Name: count, dtype: int64
#
# node 2439: 22 nodes within <= 2 hops
# cell_annotation
# tumor         11
# lymphocyte     7
# others         4
# Name: count, dtype: int64
#
# node 2440: 17 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    4
# tumor         4
# Name: count, dtype: int64
#
# node 2441: 27 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor         11
# others         5
# Name: count, dtype: int64
#
# node 2442: 26 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor          8
# others         7
# Name: count, dtype: int64
#
# node 2443: 23 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         8
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2444: 17 nodes within <= 2 hops
# cell_annotation
# others        7
# tumor         6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2445: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2446: 16 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        6
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2447: 29 nodes within <= 2 hops
# cell_annotation
# others        15
# lymphocyte    10
# tumor          4
# Name: count, dtype: int64
#
# node 2448: 22 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     7
# tumor          5
# Name: count, dtype: int64
#
# node 2449: 21 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          6
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2450: 17 nodes within <= 2 hops
# cell_annotation
# others        7
# lymphocyte    5
# tumor         5
# Name: count, dtype: int64
#
# node 2451: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         4
# Name: count, dtype: int64
#
# node 2452: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         7
# others        5
# Name: count, dtype: int64
#
# node 2453: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         3
# Name: count, dtype: int64
#
# node 2454: 20 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         6
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2455: 25 nodes within <= 2 hops
# cell_annotation
# tumor         13
# lymphocyte     6
# others         6
# Name: count, dtype: int64
#
# node 2456: 25 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# tumor          6
# others         6
# Name: count, dtype: int64
#
# node 2457: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         4
# Name: count, dtype: int64
#
# node 2458: 17 nodes within <= 2 hops
# cell_annotation
# others        7
# tumor         6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2459: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          6
# others         4
# Name: count, dtype: int64
#
# node 2460: 20 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    6
# others        5
# Name: count, dtype: int64
#
# node 2461: 28 nodes within <= 2 hops
# cell_annotation
# tumor         12
# others         9
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2462: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        7
# tumor         5
# Name: count, dtype: int64
#
# node 2463: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        8
# tumor         6
# Name: count, dtype: int64
#
# node 2464: 24 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others         7
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2465: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         5
# others        5
# Name: count, dtype: int64
#
# node 2466: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         6
# others        5
# Name: count, dtype: int64
#
# node 2467: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         6
# others        4
# Name: count, dtype: int64
#
# node 2468: 19 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        7
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2469: 29 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others        11
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2470: 13 nodes within <= 2 hops
# cell_annotation
# tumor         7
# lymphocyte    4
# others        2
# Name: count, dtype: int64
#
# node 2471: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          5
# others         5
# Name: count, dtype: int64
#
# node 2472: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         6
# others        3
# Name: count, dtype: int64
#
# node 2473: 18 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        7
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2474: 19 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         7
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2475: 26 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others        10
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2476: 19 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         7
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2477: 27 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# tumor          7
# others         7
# Name: count, dtype: int64
#
# node 2478: 21 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    7
# others        6
# Name: count, dtype: int64
#
# node 2479: 27 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor         10
# others         6
# Name: count, dtype: int64
#
# node 2480: 18 nodes within <= 2 hops
# cell_annotation
# tumor         11
# lymphocyte     5
# others         2
# Name: count, dtype: int64
#
# node 2481: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    12
# tumor          4
# others         3
# Name: count, dtype: int64
#
# node 2482: 26 nodes within <= 2 hops
# cell_annotation
# tumor         14
# lymphocyte     8
# others         4
# Name: count, dtype: int64
#
# node 2483: 20 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    7
# others        4
# Name: count, dtype: int64
#
# node 2484: 20 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2485: 24 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        8
# tumor         7
# Name: count, dtype: int64
#
# node 2486: 16 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         2
# Name: count, dtype: int64
#
# node 2487: 24 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        9
# tumor         6
# Name: count, dtype: int64
#
# node 2488: 23 nodes within <= 2 hops
# cell_annotation
# others        12
# tumor          6
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2489: 30 nodes within <= 2 hops
# cell_annotation
# others        12
# tumor         11
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2490: 19 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2491: 21 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     6
# others         5
# Name: count, dtype: int64
#
# node 2492: 20 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    6
# tumor         5
# Name: count, dtype: int64
#
# node 2493: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         6
# others        5
# Name: count, dtype: int64
#
# node 2494: 29 nodes within <= 2 hops
# cell_annotation
# others        13
# tumor         10
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2495: 22 nodes within <= 2 hops
# cell_annotation
# tumor         13
# lymphocyte     7
# others         2
# Name: count, dtype: int64
#
# node 2496: 17 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    5
# tumor         3
# Name: count, dtype: int64
#
# node 2497: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        8
# tumor         6
# Name: count, dtype: int64
#
# node 2498: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         8
# others        4
# Name: count, dtype: int64
#
# node 2499: 27 nodes within <= 2 hops
# cell_annotation
# lymphocyte    12
# tumor          9
# others         6
# Name: count, dtype: int64
#
# node 2500: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         6
# others        5
# Name: count, dtype: int64
#
# node 2501: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        6
# tumor         4
# Name: count, dtype: int64
#
# node 2502: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         6
# others        6
# Name: count, dtype: int64
#
# node 2503: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         7
# others        2
# Name: count, dtype: int64
#
# node 2504: 18 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2505: 16 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2506: 21 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        8
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2507: 25 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          9
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2508: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         5
# others        5
# Name: count, dtype: int64
#
# node 2509: 17 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2510: 15 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    4
# others        3
# Name: count, dtype: int64
#
# node 2511: 17 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    5
# others        3
# Name: count, dtype: int64
#
# node 2512: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         7
# others        5
# Name: count, dtype: int64
#
# node 2513: 25 nodes within <= 2 hops
# cell_annotation
# tumor         11
# lymphocyte     8
# others         6
# Name: count, dtype: int64
#
# node 2514: 18 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        7
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2515: 18 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2516: 31 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others        11
# lymphocyte     9
# Name: count, dtype: int64
#
# node 2517: 28 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     9
# tumor          9
# Name: count, dtype: int64
#
# node 2518: 20 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         6
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2519: 26 nodes within <= 2 hops
# cell_annotation
# lymphocyte    12
# tumor          7
# others         7
# Name: count, dtype: int64
#
# node 2520: 25 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         9
# tumor          6
# Name: count, dtype: int64
#
# node 2521: 23 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    7
# others        7
# Name: count, dtype: int64
#
# node 2522: 24 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         8
# lymphocyte    7
# Name: count, dtype: int64
#
# node 2523: 18 nodes within <= 2 hops
# cell_annotation
# others        7
# lymphocyte    6
# tumor         5
# Name: count, dtype: int64
#
# node 2524: 12 nodes within <= 2 hops
# cell_annotation
# lymphocyte    4
# tumor         4
# others        4
# Name: count, dtype: int64
#
# node 2525: 21 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        7
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2526: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        7
# tumor         4
# Name: count, dtype: int64
#
# node 2527: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         6
# others        4
# Name: count, dtype: int64
#
# node 2528: 19 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    5
# others        5
# Name: count, dtype: int64
#
# node 2529: 12 nodes within <= 2 hops
# cell_annotation
# tumor         7
# lymphocyte    3
# others        2
# Name: count, dtype: int64
#
# node 2530: 15 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        4
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2531: 26 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     8
# tumor          8
# Name: count, dtype: int64
#
# node 2532: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        6
# tumor         4
# Name: count, dtype: int64
#
# node 2533: 21 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     6
# tumor          5
# Name: count, dtype: int64
#
# node 2534: 20 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others         7
# lymphocyte     2
# Name: count, dtype: int64
#
# node 2535: 32 nodes within <= 2 hops
# cell_annotation
# tumor         16
# others         9
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2536: 19 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         5
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2537: 17 nodes within <= 2 hops
# cell_annotation
# tumor         11
# lymphocyte     3
# others         3
# Name: count, dtype: int64
#
# node 2538: 17 nodes within <= 2 hops
# cell_annotation
# others        7
# lymphocyte    5
# tumor         5
# Name: count, dtype: int64
#
# node 2539: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2540: 25 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     9
# others         6
# Name: count, dtype: int64
#
# node 2541: 22 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     7
# tumor          4
# Name: count, dtype: int64
#
# node 2542: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        8
# tumor         7
# Name: count, dtype: int64
#
# node 2543: 24 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     9
# tumor          5
# Name: count, dtype: int64
#
# node 2544: 35 nodes within <= 2 hops
# cell_annotation
# tumor         17
# lymphocyte    12
# others         6
# Name: count, dtype: int64
#
# node 2545: 16 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        6
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2546: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         4
# Name: count, dtype: int64
#
# node 2547: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         8
# others        5
# Name: count, dtype: int64
#
# node 2548: 20 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    7
# others        5
# Name: count, dtype: int64
#
# node 2549: 18 nodes within <= 2 hops
# cell_annotation
# others        7
# lymphocyte    6
# tumor         5
# Name: count, dtype: int64
#
# node 2550: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2551: 20 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         6
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2552: 18 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    5
# others        4
# Name: count, dtype: int64
#
# node 2553: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        6
# tumor         4
# Name: count, dtype: int64
#
# node 2554: 17 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2555: 22 nodes within <= 2 hops
# cell_annotation
# others        12
# lymphocyte     8
# tumor          2
# Name: count, dtype: int64
#
# node 2556: 17 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    8
# tumor         0
# Name: count, dtype: int64
#
# node 2557: 22 nodes within <= 2 hops
# cell_annotation
# tumor         12
# lymphocyte     5
# others         5
# Name: count, dtype: int64
#
# node 2558: 13 nodes within <= 2 hops
# cell_annotation
# lymphocyte    5
# tumor         4
# others        4
# Name: count, dtype: int64
#
# node 2559: 20 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2560: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         6
# Name: count, dtype: int64
#
# node 2561: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         8
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2562: 23 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     7
# tumor          5
# Name: count, dtype: int64
#
# node 2563: 24 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         9
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2564: 25 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     7
# tumor          7
# Name: count, dtype: int64
#
# node 2565: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    7
# tumor         5
# Name: count, dtype: int64
#
# node 2566: 12 nodes within <= 2 hops
# cell_annotation
# tumor         5
# lymphocyte    4
# others        3
# Name: count, dtype: int64
#
# node 2567: 29 nodes within <= 2 hops
# cell_annotation
# others        17
# lymphocyte     8
# tumor          4
# Name: count, dtype: int64
#
# node 2568: 17 nodes within <= 2 hops
# cell_annotation
# tumor         6
# others        6
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2569: 26 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          8
# others         8
# Name: count, dtype: int64
#
# node 2570: 18 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2571: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         8
# others        6
# Name: count, dtype: int64
#
# node 2572: 16 nodes within <= 2 hops
# cell_annotation
# others        6
# lymphocyte    5
# tumor         5
# Name: count, dtype: int64
#
# node 2573: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2574: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    6
# others        6
# Name: count, dtype: int64
#
# node 2575: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    12
# others         7
# tumor          4
# Name: count, dtype: int64
#
# node 2576: 21 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     7
# tumor          4
# Name: count, dtype: int64
#
# node 2577: 18 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    5
# others        5
# Name: count, dtype: int64
#
# node 2578: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# others         8
# tumor          3
# Name: count, dtype: int64
#
# node 2579: 23 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        8
# lymphocyte    7
# Name: count, dtype: int64
#
# node 2580: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# tumor          5
# others         5
# Name: count, dtype: int64
#
# node 2581: 18 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    5
# others        5
# Name: count, dtype: int64
#
# node 2582: 24 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          7
# others         7
# Name: count, dtype: int64
#
# node 2583: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        6
# tumor         3
# Name: count, dtype: int64
#
# node 2584: 17 nodes within <= 2 hops
# cell_annotation
# others        7
# lymphocyte    5
# tumor         5
# Name: count, dtype: int64
#
# node 2585: 18 nodes within <= 2 hops
# cell_annotation
# others        7
# tumor         6
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2586: 16 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    5
# tumor         2
# Name: count, dtype: int64
#
# node 2587: 20 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2588: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2589: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         6
# others        4
# Name: count, dtype: int64
#
# node 2590: 16 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    4
# others        4
# Name: count, dtype: int64
#
# node 2591: 18 nodes within <= 2 hops
# cell_annotation
# others        7
# tumor         6
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2592: 15 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        4
# tumor         3
# Name: count, dtype: int64
#
# node 2593: 16 nodes within <= 2 hops
# cell_annotation
# tumor         7
# lymphocyte    5
# others        4
# Name: count, dtype: int64
#
# node 2594: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         7
# others        4
# Name: count, dtype: int64
#
# node 2595: 24 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor          8
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2596: 22 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     7
# tumor          5
# Name: count, dtype: int64
#
# node 2597: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2598: 24 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     7
# others         7
# Name: count, dtype: int64
#
# node 2599: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# tumor          4
# others         4
# Name: count, dtype: int64
#
# node 2600: 25 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# others         7
# tumor          5
# Name: count, dtype: int64
#
# node 2601: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2602: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor          8
# others         4
# Name: count, dtype: int64
#
# node 2603: 32 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# tumor         11
# others         8
# Name: count, dtype: int64
#
# node 2604: 24 nodes within <= 2 hops
# cell_annotation
# lymphocyte    12
# tumor          7
# others         5
# Name: count, dtype: int64
#
# node 2605: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    6
# others        6
# Name: count, dtype: int64
#
# node 2606: 22 nodes within <= 2 hops
# cell_annotation
# others        13
# tumor          7
# lymphocyte     2
# Name: count, dtype: int64
#
# node 2607: 20 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         6
# Name: count, dtype: int64
#
# node 2608: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor          7
# others         5
# Name: count, dtype: int64
#
# node 2609: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    7
# tumor         5
# Name: count, dtype: int64
#
# node 2610: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         6
# others        5
# Name: count, dtype: int64
#
# node 2611: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         4
# others        3
# Name: count, dtype: int64
#
# node 2612: 22 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    8
# tumor         5
# Name: count, dtype: int64
#
# node 2613: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        8
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2614: 15 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        5
# tumor         3
# Name: count, dtype: int64
#
# node 2615: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    7
# others        5
# Name: count, dtype: int64
#
# node 2616: 24 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# others         7
# tumor          6
# Name: count, dtype: int64
#
# node 2617: 15 nodes within <= 2 hops
# cell_annotation
# tumor         7
# lymphocyte    5
# others        3
# Name: count, dtype: int64
#
# node 2618: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         6
# others        4
# Name: count, dtype: int64
#
# node 2619: 25 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     8
# tumor          6
# Name: count, dtype: int64
#
# node 2620: 19 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    6
# others        4
# Name: count, dtype: int64
#
# node 2621: 17 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    7
# others        2
# Name: count, dtype: int64
#
# node 2622: 19 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2623: 20 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         7
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2624: 23 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     8
# tumor          4
# Name: count, dtype: int64
#
# node 2625: 15 nodes within <= 2 hops
# cell_annotation
# tumor         6
# others        5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2626: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         5
# others        5
# Name: count, dtype: int64
#
# node 2627: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         7
# tumor          5
# Name: count, dtype: int64
#
# node 2628: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        7
# tumor         5
# Name: count, dtype: int64
#
# node 2629: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         7
# tumor          3
# Name: count, dtype: int64
#
# node 2630: 19 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    6
# tumor         4
# Name: count, dtype: int64
#
# node 2631: 21 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          7
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2632: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2633: 32 nodes within <= 2 hops
# cell_annotation
# others        16
# lymphocyte     9
# tumor          7
# Name: count, dtype: int64
#
# node 2634: 22 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     7
# others         5
# Name: count, dtype: int64
#
# node 2635: 23 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         7
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2636: 22 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    7
# tumor         7
# Name: count, dtype: int64
#
# node 2637: 39 nodes within <= 2 hops
# cell_annotation
# lymphocyte    17
# others        13
# tumor          9
# Name: count, dtype: int64
#
# node 2638: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         4
# Name: count, dtype: int64
#
# node 2639: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         6
# tumor          5
# Name: count, dtype: int64
#
# node 2640: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# others         6
# tumor          4
# Name: count, dtype: int64
#
# node 2641: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2642: 28 nodes within <= 2 hops
# cell_annotation
# tumor         16
# lymphocyte     6
# others         6
# Name: count, dtype: int64
#
# node 2643: 19 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2644: 25 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          8
# others         7
# Name: count, dtype: int64
#
# node 2645: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         6
# others        5
# Name: count, dtype: int64
#
# node 2646: 30 nodes within <= 2 hops
# cell_annotation
# lymphocyte    13
# others        11
# tumor          6
# Name: count, dtype: int64
#
# node 2647: 27 nodes within <= 2 hops
# cell_annotation
# others        13
# lymphocyte     7
# tumor          7
# Name: count, dtype: int64
#
# node 2648: 27 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     9
# tumor          8
# Name: count, dtype: int64
#
# node 2649: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         5
# others        5
# Name: count, dtype: int64
#
# node 2650: 26 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others         8
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2651: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         5
# others        5
# Name: count, dtype: int64
#
# node 2652: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         5
# others        5
# Name: count, dtype: int64
#
# node 2653: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2654: 21 nodes within <= 2 hops
# ...
# cell_annotation
# others        10
# lymphocyte     8
# tumor          6
# Name: count, dtype: int64
#
# node 2878: 21 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    7
# tumor         5
# Name: count, dtype: int64
#
# node 2879: 24 nodes within <= 2 hops
# cell_annotation
# tumor         12
# lymphocyte     7
# others         5
# Name: count, dtype: int64
#
# node 2880: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        7
# tumor         1
# Name: count, dtype: int64
#
# node 2881: 23 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    7
# others        7
# Name: count, dtype: int64
#
# node 2882: 24 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          9
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2883: 25 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          8
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2884: 22 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         7
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2885: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2886: 25 nodes within <= 2 hops
# cell_annotation
# tumor         14
# lymphocyte     6
# others         5
# Name: count, dtype: int64
#
# node 2887: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        7
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2888: 27 nodes within <= 2 hops
# cell_annotation
# tumor         12
# others        10
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2889: 22 nodes within <= 2 hops
# cell_annotation
# others        12
# lymphocyte     7
# tumor          3
# Name: count, dtype: int64
#
# node 2890: 18 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        7
# lymphocyte    3
# Name: count, dtype: int64
#
# node 2891: 27 nodes within <= 2 hops
# cell_annotation
# lymphocyte    14
# tumor          7
# others         6
# Name: count, dtype: int64
#
# node 2892: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# tumor          5
# others         3
# Name: count, dtype: int64
#
# node 2893: 22 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        7
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2894: 17 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         5
# lymphocyte     2
# Name: count, dtype: int64
#
# node 2895: 19 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          5
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2896: 24 nodes within <= 2 hops
# cell_annotation
# tumor         12
# others         7
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2897: 21 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         9
# lymphocyte     2
# Name: count, dtype: int64
#
# node 2898: 27 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor         10
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2899: 15 nodes within <= 2 hops
# cell_annotation
# others        6
# lymphocyte    5
# tumor         4
# Name: count, dtype: int64
#
# node 2900: 17 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2901: 28 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte    10
# tumor          7
# Name: count, dtype: int64
#
# node 2902: 24 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    8
# others        7
# Name: count, dtype: int64
#
# node 2903: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          7
# others         4
# Name: count, dtype: int64
#
# node 2904: 24 nodes within <= 2 hops
# cell_annotation
# tumor         11
# lymphocyte     7
# others         6
# Name: count, dtype: int64
#
# node 2905: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         5
# Name: count, dtype: int64
#
# node 2906: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         7
# tumor          6
# Name: count, dtype: int64
#
# node 2907: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         7
# others        6
# Name: count, dtype: int64
#
# node 2908: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         7
# others        6
# Name: count, dtype: int64
#
# node 2909: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        8
# tumor         2
# Name: count, dtype: int64
#
# node 2910: 19 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    5
# others        5
# Name: count, dtype: int64
#
# node 2911: 27 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     9
# others         8
# Name: count, dtype: int64
#
# node 2912: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    7
# others        5
# Name: count, dtype: int64
#
# node 2913: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        8
# tumor         5
# Name: count, dtype: int64
#
# node 2914: 19 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     7
# tumor          1
# Name: count, dtype: int64
#
# node 2915: 22 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         9
# lymphocyte     3
# Name: count, dtype: int64
#
# node 2916: 27 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          9
# lymphocyte     8
# Name: count, dtype: int64
#
# node 2917: 23 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         8
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2918: 16 nodes within <= 2 hops
# cell_annotation
# others        7
# tumor         5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2919: 23 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     7
# others         6
# Name: count, dtype: int64
#
# node 2920: 19 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     6
# others         3
# Name: count, dtype: int64
#
# node 2921: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         7
# others        7
# Name: count, dtype: int64
#
# node 2922: 22 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         8
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2923: 18 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     4
# tumor          4
# Name: count, dtype: int64
#
# node 2924: 25 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor         10
# others         5
# Name: count, dtype: int64
#
# node 2925: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         8
# tumor          4
# Name: count, dtype: int64
#
# node 2926: 29 nodes within <= 2 hops
# cell_annotation
# lymphocyte    14
# tumor         10
# others         5
# Name: count, dtype: int64
#
# node 2927: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    6
# others        6
# Name: count, dtype: int64
#
# node 2928: 22 nodes within <= 2 hops
# cell_annotation
# tumor         12
# others         6
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2929: 20 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         6
# lymphocyte    5
# Name: count, dtype: int64
#
# node 2930: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         6
# others        5
# Name: count, dtype: int64
#
# node 2931: 19 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          5
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2932: 27 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor          9
# lymphocyte     7
# Name: count, dtype: int64
#
# node 2933: 16 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         4
# others        3
# Name: count, dtype: int64
#
# node 2934: 16 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    7
# others        0
# Name: count, dtype: int64
#
# node 2935: 25 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     9
# tumor          5
# Name: count, dtype: int64
#
# node 2936: 18 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2937: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         7
# others        5
# Name: count, dtype: int64
#
# node 2938: 15 nodes within <= 2 hops
# cell_annotation
# tumor         7
# lymphocyte    5
# others        3
# Name: count, dtype: int64
#
# node 2939: 27 nodes within <= 2 hops
# cell_annotation
# others        14
# tumor          7
# lymphocyte     6
# Name: count, dtype: int64
#
# node 2940: 22 nodes within <= 2 hops
# cell_annotation
# others        10
# tumor          7
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2941: 18 nodes within <= 2 hops
# cell_annotation
# others        7
# lymphocyte    6
# tumor         5
# Name: count, dtype: int64
#
# node 2942: 21 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    7
# tumor         6
# Name: count, dtype: int64
#
# node 2943: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          7
# others         5
# Name: count, dtype: int64
#
# node 2944: 23 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor          9
# lymphocyte     3
# Name: count, dtype: int64
#
# node 2945: 23 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others         7
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2946: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         5
# others        4
# Name: count, dtype: int64
#
# node 2947: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         7
# others        4
# Name: count, dtype: int64
#
# node 2948: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        9
# tumor         2
# Name: count, dtype: int64
#
# node 2949: 22 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    7
# others        6
# Name: count, dtype: int64
#
# node 2950: 25 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        9
# lymphocyte    7
# Name: count, dtype: int64
#
# node 2951: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# others        7
# tumor         4
# Name: count, dtype: int64
#
# node 2952: 15 nodes within <= 2 hops
# cell_annotation
# others        6
# tumor         5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2953: 23 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# others         8
# tumor          5
# Name: count, dtype: int64
#
# node 2954: 25 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor         10
# lymphocyte     4
# Name: count, dtype: int64
#
# node 2955: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2956: 20 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     6
# tumor          4
# Name: count, dtype: int64
#
# node 2957: 21 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    7
# others        6
# Name: count, dtype: int64
#
# node 2958: 32 nodes within <= 2 hops
# cell_annotation
# others        12
# lymphocyte    10
# tumor         10
# Name: count, dtype: int64
#
# node 2959: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# others        7
# tumor         6
# Name: count, dtype: int64
#
# node 2960: 20 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        9
# lymphocyte    2
# Name: count, dtype: int64
#
# node 2961: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    7
# others        5
# Name: count, dtype: int64
#
# node 2962: 14 nodes within <= 2 hops
# cell_annotation
# tumor         6
# lymphocyte    4
# others        4
# Name: count, dtype: int64
#
# node 2963: 30 nodes within <= 2 hops
# cell_annotation
# others        11
# tumor         10
# lymphocyte     9
# Name: count, dtype: int64
#
# node 2964: 21 nodes within <= 2 hops
# cell_annotation
# tumor         10
# others         8
# lymphocyte     3
# Name: count, dtype: int64
#
# node 2965: 15 nodes within <= 2 hops
# cell_annotation
# tumor         6
# others        5
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2966: 19 nodes within <= 2 hops
# cell_annotation
# tumor         10
# lymphocyte     6
# others         3
# Name: count, dtype: int64
#
# node 2967: 18 nodes within <= 2 hops
# cell_annotation
# tumor         7
# others        7
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2968: 16 nodes within <= 2 hops
# cell_annotation
# others        6
# lymphocyte    5
# tumor         5
# Name: count, dtype: int64
#
# node 2969: 19 nodes within <= 2 hops
# cell_annotation
# others        9
# tumor         6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2970: 22 nodes within <= 2 hops
# cell_annotation
# tumor         11
# others         6
# lymphocyte     5
# Name: count, dtype: int64
#
# node 2971: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor          5
# others         3
# Name: count, dtype: int64
#
# node 2972: 19 nodes within <= 2 hops
# cell_annotation
# others        8
# lymphocyte    6
# tumor         5
# Name: count, dtype: int64
#
# node 2973: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        8
# tumor         4
# Name: count, dtype: int64
#
# node 2974: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        8
# tumor         5
# Name: count, dtype: int64
#
# node 2975: 25 nodes within <= 2 hops
# cell_annotation
# others        11
# lymphocyte     9
# tumor          5
# Name: count, dtype: int64
#
# node 2976: 17 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         6
# others        3
# Name: count, dtype: int64
#
# node 2977: 15 nodes within <= 2 hops
# cell_annotation
# lymphocyte    7
# tumor         6
# others        2
# Name: count, dtype: int64
#
# node 2978: 20 nodes within <= 2 hops
# cell_annotation
# tumor         8
# lymphocyte    6
# others        6
# Name: count, dtype: int64
#
# node 2979: 24 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        8
# lymphocyte    7
# Name: count, dtype: int64
#
# node 2980: 16 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         6
# lymphocyte    2
# Name: count, dtype: int64
#
# node 2981: 19 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        7
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2982: 18 nodes within <= 2 hops
# cell_annotation
# tumor         8
# others        6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2983: 21 nodes within <= 2 hops
# cell_annotation
# tumor         9
# others        8
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2984: 21 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         9
# others        3
# Name: count, dtype: int64
#
# node 2985: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        6
# tumor         5
# Name: count, dtype: int64
#
# node 2986: 21 nodes within <= 2 hops
# cell_annotation
# others        8
# tumor         7
# lymphocyte    6
# Name: count, dtype: int64
#
# node 2987: 20 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# tumor         6
# others        6
# Name: count, dtype: int64
#
# node 2988: 27 nodes within <= 2 hops
# cell_annotation
# lymphocyte    10
# tumor         10
# others         7
# Name: count, dtype: int64
#
# node 2989: 16 nodes within <= 2 hops
# cell_annotation
# tumor         6
# others        6
# lymphocyte    4
# Name: count, dtype: int64
#
# node 2990: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    11
# others         9
# tumor          2
# Name: count, dtype: int64
#
# node 2991: 22 nodes within <= 2 hops
# cell_annotation
# others        10
# lymphocyte     8
# tumor          4
# Name: count, dtype: int64
#
# node 2992: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         6
# others        6
# Name: count, dtype: int64
#
# node 2993: 23 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    7
# tumor         7
# Name: count, dtype: int64
#
# node 2994: 18 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# tumor         6
# others        6
# Name: count, dtype: int64
#
# node 2995: 20 nodes within <= 2 hops
# cell_annotation
# others        9
# lymphocyte    6
# tumor         5
# Name: count, dtype: int64
#
# node 2996: 19 nodes within <= 2 hops
# cell_annotation
# lymphocyte    8
# others        8
# tumor         3
# Name: count, dtype: int64
#
# node 2997: 23 nodes within <= 2 hops
# cell_annotation
# tumor         9
# lymphocyte    8
# others        6
# Name: count, dtype: int64
#
# node 2998: 15 nodes within <= 2 hops
# cell_annotation
# lymphocyte    6
# others        6
# tumor         3
# Name: count, dtype: int64
#
# node 2999: 22 nodes within <= 2 hops
# cell_annotation
# lymphocyte    9
# tumor         8
# others        5
# Name: count, dtype: int64

# %% [markdown]
# The provided code defines functions to perform Delaunay triangulation and find k-hop neighbors on a set of 2D points, simulating cell locations with annotations.
#
# Here's a breakdown:
#
# 1.  **`make_cells` function**: Creates a pandas DataFrame with random `x`, `y` coordinates and categorical `cell_annotation` labels ("lymphocyte", "tumor", "others").
#
# 2.  **`delaunay_triangulation_fast` function**:
#     *   Takes an array of points.
#     *   Performs Delaunay triangulation using `scipy.spatial.Delaunay`.
#     *   Handles potential duplicate points by finding unique points and mapping back to original indices.
#     *   Optionally returns the simplices (triangles) and edges of the triangulation.
#     *   Returns various arrays and the `Delaunay` object for further use.
#
# 3.  **`k_hop_all_nodes` function**:
#     *   Takes the `indptr_u` and `indices_u` from the Delaunay triangulation (representing unique point neighbors), original-to-unique and unique-to-original mappings, and the number of hops `k`.
#     *   Builds a symmetric boolean adjacency matrix `A` in the unique index space using `csr_matrix`.
#     *   Computes the k-hop reachability matrix `R` by repeatedly multiplying `A` with itself (boolean matrix multiplication).
#     *   Optionally includes the starting node in the neighbors (`include_start`).
#     *   Maps the unique node neighbors back to the original node indices.
#     *   Returns a list where each element is an array of original node IDs within `k` hops of the corresponding original node.
#
# 4.  **Example Usage (`if __name__ == "__main__":`)**:
#     *   Generates sample cell data using `make_cells`.
#     *   Performs Delaunay triangulation on the cell coordinates.
#     *   Calls `k_hop_all_nodes` to find 2-hop neighbors for all cells.
#     *   Prints the number of neighbors and the counts of each cell annotation type within the 2-hop neighborhood for a few example nodes.

# %% [markdown]
# # Task
# Modify the code to identify nodes with more than N neighbors (including k-hopping neighbors), and among these, find nodes where the ratio of k-hopping neighbors with annotations in `primary_annotations` to the total number of k-hopping neighbors is greater than R.

# %% [markdown]
# ## Get k-hop neighbors
#
# ### Subtask:
# Obtain the k-hop neighbors for all nodes, this time including the starting node.

# %% [markdown]
# **Reasoning**:
# Obtain the k-hop neighbors for all nodes, including the starting node, by calling the `k_hop_all_nodes` function with `include_start=True`.

# %%
neighbors_k_inclusive = k_hop_all_nodes(indptr_u, indices_u, orig2uniq, uniq2orig, k=k, include_start=True)

# %% [markdown]
# ## Identify nodes with more than n neighbors
#
# ### Subtask:
# Filter the nodes to keep only those with more than `N` neighbors.

# %% [markdown]
# **Reasoning**:
# Filter the nodes based on the number of neighbors being greater than N.

# %%
N = 25  # Define the threshold for the minimum number of neighbors

nodes_with_sufficient_neighbors = []
for i, neighbors in enumerate(neighbors_k_inclusive):
    if len(neighbors) > N:
        nodes_with_sufficient_neighbors.append(i)

print(f"Found {len(nodes_with_sufficient_neighbors)} nodes with more than {N} neighbors.")
# Out:
# Found 310 nodes with more than 25 neighbors.

# %% [markdown]
# ## Count primary annotation neighbors
#
# ### Subtask:
# For the filtered nodes, count the number of k-hop neighbors whose annotations are in `primary_annotations`.

# %% [markdown]
# **Reasoning**:
# Iterate through the filtered nodes and count the number of primary neighbors for each.

# %%
primary_annotations = ["tumor", "lymphocyte"]  # Define primary annotation types
primary_neighbor_counts = []

for node_index in nodes_with_sufficient_neighbors:
    k_hop_neighbors = neighbors_k_inclusive[node_index]
    primary_neighbors = df.loc[k_hop_neighbors, "cell_annotation"].isin(primary_annotations)
    primary_count = primary_neighbors.sum()
    primary_neighbor_counts.append(primary_count)

print(f"Calculated primary neighbor counts for {len(primary_neighbor_counts)} filtered nodes.")
# Out:
# Calculated primary neighbor counts for 310 filtered nodes.

# %% [markdown]
# ## Calculate the ratio
#
# ### Subtask:
# For the filtered nodes, calculate the ratio of primary annotation neighbors to the total number of k-hop neighbors.

# %% [markdown]
# **Reasoning**:
# Calculate the ratio of primary annotation neighbors to the total number of k-hop neighbors for each filtered node.

# %%
primary_ratios = []

for i, node_index in enumerate(nodes_with_sufficient_neighbors):
    total_neighbors = len(neighbors_k_inclusive[node_index])
    primary_count = primary_neighbor_counts[i]
    if total_neighbors > 0:
        ratio = primary_count / total_neighbors
    else:
        ratio = 0  # Should not happen based on previous filtering
    primary_ratios.append(ratio)

print(f"Calculated {len(primary_ratios)} primary ratios.")
# Out:
# Calculated 310 primary ratios.

# %% [markdown]
# ## Identify nodes meeting both criteria
#
# ### Subtask:
# Filter the nodes further to keep only those where the calculated ratio is greater than `R`.

# %% [markdown]
# **Reasoning**:
# Filter the nodes based on the primary annotation ratio threshold and print the count of resulting nodes.

# %%
R = 0.5  # Define the threshold for the minimum primary annotation ratio

nodes_meeting_both_criteria = []
for i, node_index in enumerate(nodes_with_sufficient_neighbors):
    if primary_ratios[i] > R:
        nodes_meeting_both_criteria.append(node_index)

print(f"Found {len(nodes_meeting_both_criteria)} nodes meeting both criteria (more than {N} neighbors and primary ratio > {R}).")
# Out:
# Found 295 nodes meeting both criteria (more than 25 neighbors and primary ratio > 0.5).

# %% [markdown]
# ## Present the results
#
# ### Subtask:
# Display the identified nodes and their calculated ratios.

# %% [markdown]
# **Reasoning**:
# Display the identified nodes and their calculated ratios by iterating through the list of nodes meeting both criteria and retrieving their corresponding ratios.

# %%
print("Nodes meeting both criteria and their primary ratios:")
for node_index in nodes_meeting_both_criteria:
    # Find the position of node_index in nodes_with_sufficient_neighbors
    # This assumes nodes_meeting_both_criteria is a subset of nodes_with_sufficient_neighbors
    # and maintains the relative order, which is true based on the filtering logic.
    try:
        index_in_sufficient_neighbors = nodes_with_sufficient_neighbors.index(node_index)
        ratio = primary_ratios[index_in_sufficient_neighbors]
        print(f"Node {node_index}: Ratio = {ratio:.4f}")
    except ValueError:
        # This should not happen if the logic is correct, but added for robustness
        print(f"Error: Node {node_index} not found in nodes_with_sufficient_neighbors.")
# Out:
# Nodes meeting both criteria and their primary ratios:
# Node 18: Ratio = 0.7586
# Node 39: Ratio = 0.8214
# Node 46: Ratio = 0.7143
# Node 47: Ratio = 0.7097
# Node 51: Ratio = 0.6923
# Node 71: Ratio = 0.6154
# Node 93: Ratio = 0.5714
# Node 108: Ratio = 0.7857
# Node 121: Ratio = 0.7586
# Node 142: Ratio = 0.8333
# Node 166: Ratio = 0.7500
# Node 167: Ratio = 0.5926
# Node 168: Ratio = 0.7143
# Node 176: Ratio = 0.7308
# Node 182: Ratio = 0.7037
# Node 192: Ratio = 0.6207
# Node 193: Ratio = 0.7429
# Node 199: Ratio = 0.5667
# Node 213: Ratio = 0.6296
# Node 214: Ratio = 0.7407
# Node 237: Ratio = 0.5769
# Node 242: Ratio = 0.7174
# Node 249: Ratio = 0.6154
# Node 252: Ratio = 0.7188
# Node 256: Ratio = 0.7667
# Node 261: Ratio = 0.5556
# Node 295: Ratio = 0.7037
# Node 309: Ratio = 0.7000
# Node 337: Ratio = 0.5294
# Node 351: Ratio = 0.7778
# Node 355: Ratio = 0.6538
# Node 357: Ratio = 0.7692
# Node 362: Ratio = 0.7692
# Node 371: Ratio = 0.7692
# Node 374: Ratio = 0.6667
# Node 376: Ratio = 0.5484
# Node 394: Ratio = 0.6154
# Node 397: Ratio = 0.7500
# Node 428: Ratio = 0.7407
# Node 430: Ratio = 0.5926
# Node 432: Ratio = 0.6333
# Node 433: Ratio = 0.5926
# Node 444: Ratio = 0.6071
# Node 448: Ratio = 0.6429
# Node 458: Ratio = 0.6897
# Node 476: Ratio = 0.6538
# Node 478: Ratio = 0.7037
# Node 483: Ratio = 0.6923
# Node 496: Ratio = 0.6538
# Node 517: Ratio = 0.5556
# Node 530: Ratio = 0.6538
# Node 541: Ratio = 0.6452
# Node 542: Ratio = 0.7500
# Node 563: Ratio = 0.7692
# Node 567: Ratio = 0.8077
# Node 572: Ratio = 0.7308
# Node 585: Ratio = 0.7333
# Node 604: Ratio = 0.6538
# Node 614: Ratio = 0.7308
# Node 617: Ratio = 0.5833
# Node 622: Ratio = 0.5185
# Node 625: Ratio = 0.6667
# Node 646: Ratio = 0.6667
# Node 658: Ratio = 0.7308
# Node 671: Ratio = 0.5333
# Node 676: Ratio = 0.7308
# Node 680: Ratio = 0.6875
# Node 693: Ratio = 0.6071
# Node 700: Ratio = 0.7333
# Node 731: Ratio = 0.5185
# Node 740: Ratio = 0.7037
# Node 759: Ratio = 0.5714
# Node 793: Ratio = 0.7308
# Node 799: Ratio = 0.5882
# Node 800: Ratio = 0.6286
# Node 801: Ratio = 0.7308
# Node 832: Ratio = 0.6923
# Node 844: Ratio = 0.6000
# Node 847: Ratio = 0.5385
# Node 858: Ratio = 0.6429
# Node 865: Ratio = 0.7241
# Node 890: Ratio = 0.6923
# Node 897: Ratio = 0.7407
# Node 901: Ratio = 0.6786
# Node 907: Ratio = 0.7500
# Node 910: Ratio = 0.6071
# Node 912: Ratio = 0.6538
# Node 914: Ratio = 0.8182
# Node 930: Ratio = 0.6667
# Node 944: Ratio = 0.7308
# Node 946: Ratio = 0.6296
# Node 949: Ratio = 0.6923
# Node 961: Ratio = 0.5556
# Node 971: Ratio = 0.6538
# Node 987: Ratio = 0.7000
# Node 997: Ratio = 0.8125
# Node 1033: Ratio = 0.8148
# Node 1050: Ratio = 0.7586
# Node 1060: Ratio = 0.7778
# Node 1071: Ratio = 0.5714
# Node 1084: Ratio = 0.7037
# Node 1111: Ratio = 0.6774
# Node 1127: Ratio = 0.5385
# Node 1130: Ratio = 0.7188
# Node 1139: Ratio = 0.5294
# Node 1149: Ratio = 0.6786
# Node 1155: Ratio = 0.6667
# Node 1163: Ratio = 0.6296
# Node 1182: Ratio = 0.6667
# Node 1203: Ratio = 0.6923
# Node 1206: Ratio = 0.6154
# Node 1207: Ratio = 0.7400
# Node 1212: Ratio = 0.7692
# Node 1214: Ratio = 0.5926
# Node 1223: Ratio = 0.5294
# Node 1224: Ratio = 0.6071
# Node 1228: Ratio = 0.6200
# Node 1234: Ratio = 0.7419
# Node 1236: Ratio = 0.7857
# Node 1248: Ratio = 0.6207
# Node 1304: Ratio = 0.5556
# Node 1336: Ratio = 0.7778
# Node 1341: Ratio = 0.7308
# Node 1347: Ratio = 0.5714
# Node 1359: Ratio = 0.7143
# Node 1360: Ratio = 0.5769
# Node 1379: Ratio = 0.6667
# Node 1388: Ratio = 0.6667
# Node 1398: Ratio = 0.7241
# Node 1399: Ratio = 0.5172
# Node 1424: Ratio = 0.7188
# Node 1445: Ratio = 0.6552
# Node 1468: Ratio = 0.5385
# Node 1482: Ratio = 0.6129
# Node 1507: Ratio = 0.5333
# Node 1508: Ratio = 0.6538
# Node 1517: Ratio = 0.7000
# Node 1520: Ratio = 0.6757
# Node 1533: Ratio = 0.7419
# Node 1545: Ratio = 0.6786
# Node 1552: Ratio = 0.7037
# Node 1573: Ratio = 0.7407
# Node 1579: Ratio = 0.5862
# Node 1581: Ratio = 0.5385
# Node 1582: Ratio = 0.6071
# Node 1585: Ratio = 0.8065
# Node 1615: Ratio = 0.6538
# Node 1622: Ratio = 0.7241
# Node 1629: Ratio = 0.5312
# Node 1635: Ratio = 0.6786
# Node 1640: Ratio = 0.6296
# Node 1667: Ratio = 0.6538
# Node 1669: Ratio = 0.7143
# Node 1684: Ratio = 0.7407
# Node 1689: Ratio = 0.6667
# Node 1718: Ratio = 0.8889
# Node 1728: Ratio = 0.7308
# Node 1733: Ratio = 0.5714
# Node 1735: Ratio = 0.6538
# Node 1748: Ratio = 0.7241
# Node 1754: Ratio = 0.6071
# Node 1758: Ratio = 0.6538
# Node 1762: Ratio = 0.7308
# Node 1784: Ratio = 0.6552
# Node 1786: Ratio = 0.6429
# Node 1793: Ratio = 0.7931
# Node 1807: Ratio = 0.7037
# Node 1823: Ratio = 0.6538
# Node 1844: Ratio = 0.6538
# Node 1849: Ratio = 0.6923
# Node 1853: Ratio = 0.7692
# Node 1857: Ratio = 0.7407
# Node 1866: Ratio = 0.5806
# Node 1871: Ratio = 0.7037
# Node 1874: Ratio = 0.7632
# Node 1888: Ratio = 0.5862
# Node 1907: Ratio = 0.6786
# Node 1948: Ratio = 0.6154
# Node 1949: Ratio = 0.5714
# Node 1950: Ratio = 0.6923
# Node 1955: Ratio = 0.5172
# Node 1957: Ratio = 0.6923
# Node 1960: Ratio = 0.6750
# Node 1968: Ratio = 0.6667
# Node 1984: Ratio = 0.7037
# Node 1993: Ratio = 0.7308
# Node 1997: Ratio = 0.7037
# Node 2000: Ratio = 0.6333
# Node 2004: Ratio = 0.6786
# Node 2019: Ratio = 0.6154
# Node 2020: Ratio = 0.7778
# Node 2036: Ratio = 0.5862
# Node 2038: Ratio = 0.6429
# Node 2042: Ratio = 0.7308
# Node 2045: Ratio = 0.7500
# Node 2057: Ratio = 0.6667
# Node 2059: Ratio = 0.6296
# Node 2061: Ratio = 0.6333
# Node 2082: Ratio = 0.7576
# Node 2086: Ratio = 0.6429
# Node 2099: Ratio = 0.6923
# Node 2108: Ratio = 0.7308
# Node 2116: Ratio = 0.5769
# Node 2127: Ratio = 0.6538
# Node 2128: Ratio = 0.6774
# Node 2135: Ratio = 0.8846
# Node 2137: Ratio = 0.6667
# Node 2143: Ratio = 0.6296
# Node 2156: Ratio = 0.5185
# Node 2194: Ratio = 0.7778
# Node 2201: Ratio = 0.7778
# Node 2204: Ratio = 0.5769
# Node 2212: Ratio = 0.6296
# Node 2221: Ratio = 0.5814
# Node 2223: Ratio = 0.6552
# Node 2234: Ratio = 0.6154
# Node 2244: Ratio = 0.6786
# Node 2261: Ratio = 0.8387
# Node 2269: Ratio = 0.6296
# Node 2285: Ratio = 0.7037
# Node 2305: Ratio = 0.7308
# Node 2308: Ratio = 0.5172
# Node 2309: Ratio = 0.6538
# Node 2317: Ratio = 0.7308
# Node 2349: Ratio = 0.6731
# Node 2357: Ratio = 0.8077
# Node 2359: Ratio = 0.6538
# Node 2361: Ratio = 0.7931
# Node 2364: Ratio = 0.5769
# Node 2389: Ratio = 0.5172
# Node 2398: Ratio = 0.7308
# Node 2402: Ratio = 0.7308
# Node 2418: Ratio = 0.6923
# Node 2423: Ratio = 0.8148
# Node 2425: Ratio = 0.7778
# Node 2432: Ratio = 0.7931
# Node 2438: Ratio = 0.6061
# Node 2441: Ratio = 0.8148
# Node 2442: Ratio = 0.7308
# Node 2461: Ratio = 0.6786
# Node 2469: Ratio = 0.6207
# Node 2475: Ratio = 0.6154
# Node 2477: Ratio = 0.7407
# Node 2479: Ratio = 0.7778
# Node 2482: Ratio = 0.8462
# Node 2489: Ratio = 0.6000
# Node 2494: Ratio = 0.5517
# Node 2499: Ratio = 0.7778
# Node 2516: Ratio = 0.6452
# Node 2517: Ratio = 0.6429
# Node 2519: Ratio = 0.7308
# Node 2531: Ratio = 0.6154
# Node 2535: Ratio = 0.7188
# Node 2544: Ratio = 0.8286
# Node 2569: Ratio = 0.6923
# Node 2603: Ratio = 0.7500
# Node 2637: Ratio = 0.6667
# Node 2642: Ratio = 0.7857
# Node 2646: Ratio = 0.6333
# Node 2647: Ratio = 0.5185
# Node 2648: Ratio = 0.6296
# Node 2650: Ratio = 0.6923
# Node 2660: Ratio = 0.6786
# Node 2703: Ratio = 0.5926
# Node 2717: Ratio = 0.7407
# Node 2722: Ratio = 0.6552
# Node 2737: Ratio = 0.6923
# Node 2747: Ratio = 0.7037
# Node 2748: Ratio = 0.7143
# Node 2758: Ratio = 0.7143
# Node 2761: Ratio = 0.5806
# Node 2763: Ratio = 0.6429
# Node 2764: Ratio = 0.7407
# Node 2775: Ratio = 0.7308
# Node 2778: Ratio = 0.8214
# Node 2791: Ratio = 0.6154
# Node 2792: Ratio = 0.6071
# Node 2796: Ratio = 0.8148
# Node 2803: Ratio = 0.6744
# Node 2834: Ratio = 0.5833
# Node 2840: Ratio = 0.6552
# Node 2843: Ratio = 0.6538
# Node 2850: Ratio = 0.7941
# Node 2869: Ratio = 0.6429
# Node 2888: Ratio = 0.6296
# Node 2891: Ratio = 0.7778
# Node 2898: Ratio = 0.5926
# Node 2901: Ratio = 0.6071
# Node 2911: Ratio = 0.7037
# Node 2916: Ratio = 0.6296
# Node 2926: Ratio = 0.8276
# Node 2932: Ratio = 0.5926
# Node 2958: Ratio = 0.6250
# Node 2963: Ratio = 0.6333
# Node 2988: Ratio = 0.7407

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   295 nodes were identified that have more than 25 neighbors (including k-hop neighbors) and a ratio of primary annotated k-hop neighbors (tumor or lymphocyte) to total k-hop neighbors greater than 0.5.
# *   The specific primary annotation types considered were "tumor" and "lymphocyte".
#
# ### Insights or Next Steps
#
# *   The identified nodes represent areas in the graph where there is a high concentration of primary annotated cells within their k-hop neighborhood. Further investigation into the characteristics and spatial location of these nodes could provide insights into biological patterns.
# *   Consider visualizing these identified nodes on the original image to understand their spatial distribution relative to different tissue structures and cell types.

# %%
import matplotlib.pyplot as plt

def generate_binary_image(nodes_to_highlight, df, width, height, mpp):
    """
    Generates a binary image highlighting the specified nodes.

    Args:
        nodes_to_highlight (list): A list of node indices to highlight in the image.
        df (pd.DataFrame): The DataFrame containing node coordinates ('x', 'y').
        width (int): The width of the original image in pixels.
        height (int): The height of the original image in pixels.
        mpp (float): Microns per pixel, used to scale coordinates if necessary
                     (although in this case we are using pixel coordinates directly).

    Returns:
        np.ndarray: A 2D numpy array representing the binary image.
    """
    # Create a blank binary image
    binary_image = np.zeros((height, width), dtype=np.uint8)

    # Mark the specified nodes on the image
    for node_index in nodes_to_highlight:
        x, y = df.loc[node_index, ['x', 'y']].values
        # Ensure coordinates are within image bounds and cast to integers
        x_int, y_int = int(round(x)), int(round(y))
        if 0 <= x_int < width and 0 <= y_int < height:
            binary_image[y_int, x_int] = 1 # Mark the pixel with 1

    return binary_image

# Example usage (assuming 'nodes_meeting_both_criteria' is the list of identified nodes)
# You would call this function after running the previous steps to get nodes_meeting_both_criteria
# binary_map = generate_binary_image(nodes_meeting_both_criteria, df, 2048, 2048, 0.5) # Example mpp
# plt.imshow(binary_map, cmap='gray')
# plt.title("Binary Map of Identified Nodes")
# plt.show()
